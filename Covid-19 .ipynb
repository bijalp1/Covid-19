# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
import plotly.express as px
import plotly.graph_objects as go
from statistics import median, mean, mode

# %%
dataset = pd.read_csv('/Users/pratikzaveri/Desktop/Dataset/Covid_Data.csv')
dataset
# Out:
#          USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  \
# 0            2             1    1             1  03/05/2020       97
# 1            2             1    2             1  03/06/2020       97
# 2            2             1    2             2  09/06/2020        1
# 3            2             1    1             1  12/06/2020       97
# 4            2             1    2             1  21/06/2020       97
# ...        ...           ...  ...           ...         ...      ...
# 1048570      2            13    2             1  9999-99-99       97
# 1048571      1            13    2             2  9999-99-99        2
# 1048572      2            13    2             1  9999-99-99       97
# 1048573      2            13    2             1  9999-99-99       97
# 1048574      2            13    2             1  9999-99-99       97
#
#          PNEUMONIA  AGE  PREGNANT  DIABETES  ...  ASTHMA  INMSUPR  \
# 0                1   65         2         2  ...       2        2
# ...

# %% [markdown]
# # Total number of Male Vs. Female

# %%
df = pd.read_csv('/Users/pratikzaveri/Desktop/Dataset/Covid_Data.csv')

# Count for total number of females (where gender is 1)
total_females = (df['SEX'] == 1).sum()

# Count for total number of males (where gender is 2)
total_males = (df['SEX'] == 2).sum()

# Display the results
print(f'Total Females: {total_females}')
print(f'Total Males: {total_males}')

# Bar graph
plt.bar(['Female', 'Male'], [total_females, total_males], color=['pink', 'blue'])
plt.xlabel('SEX')
plt.ylabel('Total Count')
plt.title('Total Number of Males and Females in the Dataset')
plt.text(0, total_females + 5, str(total_females), ha='center', va='bottom')
plt.text(1, total_males + 5, str(total_males), ha='center', va='bottom')

plt.show()
# Out:
# Total Females: 525064
# Total Males: 523511

# %% [markdown]
# # Age Distribution

# %%
df = pd.read_csv('/Users/pratikzaveri/Desktop/Dataset/Covid_Data.csv')

# Plotting the histogram for age distribution

plt.hist(df['AGE'], bins=20, color='skyblue', edgecolor='black')
plt.title('Age Distribution in the Dataset')
plt.xlabel('AGE')
plt.ylabel('Count')
plt.grid(axis='y', alpha=0.75)
plt.show()

# %% [markdown]
# # Total Patients Alive vs. Dead

# %%
df = pd.read_csv('/Users/pratikzaveri/Desktop/Dataset/Covid_Data.csv')

# Count for total number of patients (alive as well as died)
total_counts = df['DATE_DIED'].value_counts()

# Count for total number of patients alive (where date died = 9999-99-99)
Alive = (df['DATE_DIED'] == '9999-99-99').sum()

# Count for total number of patients dead (where date died != 9999-99-99)
Died = (df['DATE_DIED'] != '9999-99-99' ).sum()


print(f'Total Number of Patients Died: {Died}')
print(f'Total Number of patients Alive: {Alive}')

# Bar graph
plt.bar(['Alive','Died'], [alive, died], color =['purple','pink'])
plt.xlabel('Patient status')
plt.ylabel('Number of Patients')
plt.title('Total number of Patients Died vs. Alive')
plt.text(0, Alive + 5, str(Alive), ha='center', va='bottom')
plt.text(1, Died + 5, str(Died), ha='center', va='bottom')
plt.show()
# Out:
# Total Number of Patients Died: 76942
# Total Number of patients Alive: 971633

# %% [markdown]
# # Total Patient Returned Home vs. Hospitalized

# %%
df = pd.read_csv('/Users/pratikzaveri/Desktop/Dataset/Covid_Data.csv')

# Count the number of patients with status 1 (returned home) and status 2 (hospitalized)
status_counts = df['PATIENT_TYPE'].value_counts()

# Count for total number of patients returned home (where Patient type is 1)
returned_home = (df['PATIENT_TYPE'] == 1).sum()

# Count for total number of patients hospitalized (where patient type is 2)
hospitalized = (df['PATIENT_TYPE'] == 2).sum()

# Display the results
print(f'Total Patients returned home: {returned_home}')
print(f'Total Patients Hospitalized: {hospitalized}')

# Plot the results
plt.bar(status_counts.index, status_counts.values, color=['green', 'red'])
plt.xlabel('Patient Type')
plt.ylabel('Number of Patients')
plt.title('Total Number of Patients Returned Home vs. Hospitalized')
plt.text(1, returned_home + 5, str(returned_home), ha='center', va='bottom')
plt.text(2, hospitalized + 5, str(hospitalized), ha='center', va='bottom')
plt.xticks(status_counts.index, ['Returned Home', 'Hospitalized'])
plt.show()
# Out:
# Total Patients returned home: 848544
# Total Patients Hospitalized: 200031

# %% [markdown]
# # Total Patient with Diabetes vs without Diabetes

# %%
df = pd.read_csv('/Users/pratikzaveri/Desktop/Dataset/Covid_Data.csv')

# Count the total number of patients with asthma (ASTHMA = 1)
diabetes_yes = (df['DIABETES'] == 1).sum()

# Count the total number of patients without asthma (ASTHMA = 2)
diabetes_no = (df['DIABETES'] == 2).sum()

# Bar graph
plt.bar(['Yes', 'No'], [diabetes_yes, diabetes_no], color=['red', 'yellow'])
plt.text(0, diabetes_yes + 5, str(diabetes_yes), ha='center', va='bottom')
plt.text(1, diabetes_no + 5, str(diabetes_no), ha='center', va='bottom')
plt.xlabel('Diabetes Status')
plt.ylabel('Number of Patients')
plt.title('Total Number of Patients with Diabetes vs. Without Diabetes')
plt.show()

# %% [markdown]
# # Total Patients with Asthama vs. without Asthama

# %%
df = pd.read_csv('/Users/pratikzaveri/Desktop/Dataset/Covid_Data.csv')

# Count the total number of patients with asthma (ASTHMA = 1)
asthma_yes = (df['ASTHMA'] == 1).sum()

# Count the total number of patients without asthma (ASTHMA = 2)
asthma_no = (df['ASTHMA'] == 2).sum()

# Bar graph
plt.bar(['Yes', 'No'], [asthma_yes, asthma_no], color=['blue', 'orange'])
plt.text(0, asthma_yes + 5, str(asthma_yes), ha='center', va='bottom')
plt.text(1, asthma_no + 5, str(asthma_no), ha='center', va='bottom')
plt.xlabel('Asthma Status')
plt.ylabel('Number of Patients')
plt.title('Total Number of Patients with Asthma vs. Without Asthma')
plt.show()

# %% [markdown]
# # Total Patient with Hipertension vs without Hipertension

# %%
df = pd.read_csv('/Users/pratikzaveri/Desktop/Dataset/Covid_Data.csv')

# Count the total number of patients with asthma (ASTHMA = 1)
hipertension_yes = (df['HIPERTENSION'] == 1).sum()

# Count the total number of patients without asthma (ASTHMA = 2)
hipertension_no = (df['HIPERTENSION'] == 2).sum()

# Bar graph
plt.bar(['Yes', 'No'], [hipertension_yes, hipertension_no], color=['blue', 'skyblue'])
plt.text(0, hipertension_yes + 5, str(hipertension_yes), ha='center', va='bottom')
plt.text(1, hipertension_no + 5, str(hipertension_no), ha='center', va='bottom')
plt.xlabel('Hipertension Status')
plt.ylabel('Number of Patients')
plt.title('Total Number of Patients with Hipertension vs. Without Hipertension')
plt.show()

# %% [markdown]
# # Total Patient with Pneumonia vs without Pneumonia

# %%
df = pd.read_csv('/Users/pratikzaveri/Desktop/Dataset/Covid_Data.csv')

# Count the total number of patients with asthma (ASTHMA = 1)
df = pd.read_csv('/Users/pratikzaveri/Desktop/Dataset/Covid_Data.csv')

# Count the total number of patients with asthma (ASTHMA = 1)
Pneumonia_yes = (df['PNEUMONIA'] == 1).sum()

# Count the total number of patients without asthma (ASTHMA = 2)
Pneumonia_no = (df['PNEUMONIA'] == 2).sum()

# Bar graph
plt.bar(['Yes', 'No'], [Pneumonia_yes, Pneumonia_no], color=['darkred', 'pink'])
plt.text(0, Pneumonia_yes + 5, str(Pneumonia_yes), ha='center', va='bottom')
plt.text(1, Pneumonia_no + 5, str(Pneumonia_no), ha='center', va='bottom')
plt.xlabel('Pneumonia Status')
plt.ylabel('Number of Patients')
plt.title('Total Number of Patients with Pneumonia vs. Without Pneumonia')
plt.show()

# %% [markdown]
# # Total Patient with Cardiovascular vs without Cardiovascular

# %%
df = pd.read_csv('/Users/pratikzaveri/Desktop/Dataset/Covid_Data.csv')

# Count the total number of patients with asthma (ASTHMA = 1)
df = pd.read_csv('/Users/pratikzaveri/Desktop/Dataset/Covid_Data.csv')

# Count the total number of patients with asthma (ASTHMA = 1)
Cardiovascular_yes = (df['CARDIOVASCULAR'] == 1).sum()

# Count the total number of patients without asthma (ASTHMA = 2)
Cardiovascular_no = (df['CARDIOVASCULAR'] == 2).sum()

# Bar graph
plt.bar(['Yes', 'No'], [Cardiovascular_yes, Cardiovascular_no], color=['orange', 'yellow'])
plt.text(0, Cardiovascular_yes + 5, str(Cardiovascular_yes), ha='center', va='bottom')
plt.text(1, Cardiovascular_no + 5, str(Cardiovascular_no), ha='center', va='bottom')
plt.xlabel('Cardiovascular Status')
plt.ylabel('Number of Patients')
plt.title('Total Number of Patients with Pneumonia vs. Without Pneumonia')
plt.show()

# %% [markdown]
# # Patients with Underlying medical Condition (medthod 1)

# %%
df = pd.read_csv('/Users/pratikzaveri/Desktop/Dataset/Covid_Data.csv')

# Count the total number of patients with asthma (ASTHMA = 1)
asthma = (df['ASTHMA'] == 1).sum()

# Count the total number of patients with diabetes (diabeted = 1)
diabetes = (df['DIABETES'] == 1).sum()

# Count the total number of patients with hipertension (hipertension = 1)
hyperten = (df['HIPERTENSION'] == 1).sum()

# Count the total number of patients with cardiovascular(Cardiovascular = 1)
cardiovasc = (df['CARDIOVASCULAR'] == 1).sum()

# Count the total number of patients with pneumonia (pneumonia = 1)
pneumonia = (df['PNEUMONIA'] == 1).sum()

# Count the total number of patients with obesity (obesity = 1)
obesity = (df['OBESITY'] == 1).sum()

# Count the total number of patients with inmsupr (inmsupr = 1)
inmsupr = (df['INMSUPR'] == 1).sum()

# Count the total number of patients with renal_chronic (renal_chronic = 1)
renal = (df['RENAL_CHRONIC'] == 1).sum()

# Count the total number of patients with tobacco_user (tobacco_user = 1)
tobacco_user = (df['TOBACCO'] == 1).sum()
plt.figure(figsize=(10, 6))

# Bar graph
plt.bar(['Asthma', 'Diabetes', 'Hyperten', 'Cardiovasc', 'Pneumonia', 'Obesity', 'Inmsupr', 'Renal', 'Tobacco_user'], [asthma, diabetes, hyperten, cardiovasc, pneumonia, obesity, inmsupr, renal, tobacco_user], color=['orange', 'yellow', 'red', 'blue', 'purple', 'green', 'skyblue', 'pink','magenta'])
plt.text(0, asthma + 5, str(asthma), ha='center', va='bottom')
plt.text(1, diabetes + 5, str(diabetes), ha='center', va='bottom')
plt.text(2, hyperten + 5, str(hyperten), ha='center', va='bottom')
plt.text(3, cardiovasc + 5, str(cardiovasc), ha='center', va='bottom')
plt.text(4, pneumonia + 5, str(pneumonia), ha='center', va='bottom')
plt.text(5, obesity + 5, str(obesity), ha='center', va='bottom')
plt.text(6, inmsupr + 5, str(inmsupr), ha='center', va='bottom')
plt.text(7, renal + 5, str(renal), ha='center', va='bottom')
plt.text(8, tobacco_user + 5, str(tobacco_user), ha='center', va='bottom')

plt.xlabel('Underlying Medical Condition')
plt.ylabel('Number of Patients')
plt.title('Disease')
plt.show()

# %% [markdown]
# # Patients with Underlying medical Condition (medthod 2)

# %%
df = pd.read_csv('/Users/pratikzaveri/Desktop/Dataset/Covid_Data.csv')

# List of underlying medical conditions
conditions = ['ASTHMA', 'DIABETES', 'HIPERTENSION', 'CARDIOVASCULAR', 'PNEUMONIA', 'OBESITY', 'INMSUPR', 'RENAL_CHRONIC', 'TOBACCO']

# Count for total number of patients for each condition
counts = [(df[condition] == 1).sum() for condition in conditions]
plt.figure(figsize=(10, 6))
# Bar graph
plt.bar(conditions, counts, color=['orange', 'yellow', 'red', 'blue', 'purple', 'green', 'skyblue', 'pink', 'magenta'])

# Text annotations for each bar
for i, count in enumerate(counts):
    plt.text(i, count + 5, str(count), ha='center', va='bottom')

plt.xlabel('Underlying Medical Condition')
plt.ylabel('Number of Patients')
plt.title('Disease')
plt.show()

# %%
import pandas as pd

df = pd.read_csv('/Users/pratikzaveri/Desktop/Dataset/Covid_Data.csv')

# Explore relevant features
print(df.head())
print(df.info())
# Out:
#    USMER  MEDICAL_UNIT  SEX  PATIENT_TYPE   DATE_DIED  INTUBED  PNEUMONIA  \
# 0      2             1    1             1  03/05/2020       97          1
# 1      2             1    2             1  03/06/2020       97          1
# 2      2             1    2             2  09/06/2020        1          2
# 3      2             1    1             1  12/06/2020       97          2
# 4      2             1    2             1  21/06/2020       97          2
#
#    AGE  PREGNANT  DIABETES  ...  ASTHMA  INMSUPR  HIPERTENSION  OTHER_DISEASE  \
# 0   65         2         2  ...       2        2             1              2
# 1   72        97         2  ...       2        2             1              2
# 2   55        97         1  ...       2        2             2              2
# 3   53         2         2  ...       2        2             2              2
# 4   68        97         1  ...       2        2             1              2
#
# ...
